# %% [markdown]
# # MeteOsona Data Scrapping

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
import datetime
import logging
import json
import matplotlib.pyplot as plt

# %% [markdown]
# ## Meteosona metadata scrapping

# %%
url = "https://www.meteosona.com/"
response = requests.get(url)

soup = BeautifulSoup(response.content, 'html.parser')

script_tag = soup.find('script', text=lambda text: text and 'var estacions =' in text)

if script_tag:
    estacions_variable = script_tag.text
    start_index = estacions_variable.find('var estacions = ') + len('var estacions = ')
    end_index = estacions_variable.find(';', start_index)
    estacions_data = estacions_variable[start_index:end_index]
    estacions_dict = json.loads(estacions_data, parse_constant=lambda x: None)
    
else:
    print("Unable to locate the 'estacions' variable on the website. :(")
# Out:
# /var/folders/76/bszhb_2s2k96xxhr9gsw39w80000gn/T/ipykernel_11935/1240470503.py:6: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   script_tag = soup.find('script', text=lambda text: text and 'var estacions =' in text)

# %% [markdown]
# ## Meteosona station scrapping

# %%
#create construction dataframe and results dataframe
column_names = ['day', 
                'daily precipitation (l/m2)', 
                'temperature max (C)','temperature min (C)', 'temperature mean (C)',
                'humidity max (%)', 'humidity min (%)', 'humidity mean (%)',
                'wind max (km/h)', 'wind dir', 
                'pressure max (hPa)', 'pressure min (hPa)', 'pressure mean (hPa)',
                'solar irradiation (J/m2)',
                'date','latitude', 'longitude', 'altitude (m)', 'estacio' ]
df_res = pd.DataFrame(columns=column_names)
for estacio_k in estacions_dict.keys():
    estacio=estacions_dict[estacio_k]
    logging.warning(f'Loading estació {estacio["nom"]}...')
    found_estacio=False
    for year in range(2023, 1900, -1):
        found_year=False
        months = [i+1 for i in range(13)]
        months = months[:6] if year==2023 else months
        for month in months:
            url = f'https://www.meteosona.com/estacio/{estacio["nom_url"]}/{str(month)}/{str(year)}/#sectEstacionsResum'
            # Send a GET request to the website
            response = requests.get(url)
            if response.ok:
                soup = BeautifulSoup(response.content, 'html.parser')

                table = soup.find('table', {'id': 'taula_estacio'})

                data = []
                for row in table.find_all('tr'):
                    row_data = []

                    #add html table data
                    for cell in row.find_all('td'):
                        row_data.append(cell.text.strip())
                    if len(row_data)==14:
                        #add date
                        row_data.append(datetime.date(year, month, int(row_data[0])))
                        #add lat, lon & altitude
                        row_data.append(estacio['latitud'])
                        row_data.append(estacio['longitud'])
                        row_data.append(estacio['altitud'])
                        row_data.append(estacio['nom'])
                        data.append(row_data)
                        if not found_estacio:
                            logging.warning('Found data !')
                            found_estacio=True
                        if not found_year:
                            found_year=True

                if len(data)>0:
                    new_rows_df = pd.DataFrame(data, columns=df_res.columns)

                    # Append the new row to the existing dataframe
                    df_res = pd.concat([df_res, new_rows_df], ignore_index=True)
            #if no data found for given year, don't check the next one.
        if not found_year:
            if found_estacio:
                logging.warning(f'last data for {estacio["nom"]} is {year+1}')
            break
    if not found_estacio:
        logging.warning(f'No data found for {estacio["nom"]}')

df_res.to_csv('data/meteosona/all_estacions.csv')
# Out:
# WARNING:root:Loading estació Alpens...
# WARNING:root:Found data !
# WARNING:root:last data for Alpens is 2015
# WARNING:root:Loading estació Bellmunt NW...
# WARNING:root:No data found for Bellmunt NW
# WARNING:root:Loading estació Bellmunt...
# WARNING:root:Found data !
# WARNING:root:last data for Bellmunt is 2016
# WARNING:root:Loading estació Bojons - St.Sadurní Osormort...
# WARNING:root:Found data !
# WARNING:root:last data for Bojons - St.Sadurní Osormort is 2019
# WARNING:root:Loading estació LA SELVA DEL CAMP-Baix Camp...
# WARNING:root:No data found for LA SELVA DEL CAMP-Baix Camp
# WARNING:root:Loading estació DAS-Cerdanya...
# WARNING:root:No data found for DAS-Cerdanya
# WARNING:root:Loading estació DAS-Cerdanya...
# WARNING:root:No data found for DAS-Cerdanya
# WARNING:root:Loading estació MIERES-Garrotxa...
# WARNING:root:No data found for MIERES-Garrotxa
# WARNING:root:Loading estació MIERES-Garrotxa...
# WARNING:root:No data found for MIERES-Garrotxa
# WARNING:root:Loading estació GOMBRÈN-Ripollès...
# WARNING:root:No data found for GOMBRÈN-Ripollès
# WARNING:root:Loading estació MONTGRONY-Ripollès...
# WARNING:root:No data found for MONTGRONY-Ripollès
# WARNING:root:Loading estació NÚRIA-Ripollès N...
# WARNING:root:No data found for NÚRIA-Ripollès N
# WARNING:root:Loading estació NÚRIA-Ripollès S...
# WARNING:root:No data found for NÚRIA-Ripollès S
# WARNING:root:Loading estació PLANOLES-Ripollès...
# WARNING:root:No data found for PLANOLES-Ripollès
# WARNING:root:Loading estació Calldetenes...
# WARNING:root:Found data !
# WARNING:root:last data for Calldetenes is 2014
# WARNING:root:Loading estació Calldetenes IES...
# WARNING:root:Found data !
# WARNING:root:last data for Calldetenes IES is 2017
# WARNING:root:Loading estació Cantonigròs W...
# WARNING:root:No data found for Cantonigròs W
# WARNING:root:Loading estació Cantonigròs N...
# WARNING:root:No data found for Cantonigròs N
# WARNING:root:Loading estació Cantonigròs...
# WARNING:root:Found data !
# WARNING:root:last data for Cantonigròs is 2020
# WARNING:root:Loading estació Centelles IES...
# WARNING:root:Found data !
# WARNING:root:last data for Centelles IES is 2015
# WARNING:root:Loading estació Centelles Sud...
# WARNING:root:Found data !
# WARNING:root:last data for Centelles Sud is 2015
# WARNING:root:Loading estació Ciuret SW...
# WARNING:root:No data found for Ciuret SW
# WARNING:root:Loading estació Collsuspina Centre...
# WARNING:root:Found data !
# WARNING:root:last data for Collsuspina Centre is 2018
# WARNING:root:Loading estació Cussons...
# WARNING:root:Found data !
# WARNING:root:last data for Cussons is 2016
# WARNING:root:Loading estació Els Munts Guilleries...
# WARNING:root:Found data !
# WARNING:root:last data for Els Munts Guilleries is 2015
# WARNING:root:Loading estació Els Munts-S.Agustí NW...
# WARNING:root:No data found for Els Munts-S.Agustí NW
# WARNING:root:Loading estació Els Munts-S.Agustí...
# WARNING:root:No data found for Els Munts-S.Agustí
# WARNING:root:Loading estació Espinelves...
# WARNING:root:Found data !
# WARNING:root:last data for Espinelves is 2014
# WARNING:root:Loading estació Gurb "El Serrat"...
# WARNING:root:Found data !
# WARNING:root:last data for Gurb "El Serrat" is 2014
# WARNING:root:Loading estació Gurb Escoles...
# WARNING:root:Found data !
# WARNING:root:last data for Gurb Escoles is 2014
# WARNING:root:Loading estació Hostalets de Balenyà...
# WARNING:root:Found data !
# WARNING:root:last data for Hostalets de Balenyà is 2015
# WARNING:root:Loading estació La Gleva...
# WARNING:root:Found data !
# WARNING:root:last data for La Gleva is 2015
# WARNING:root:Loading estació L'Avenc - Tavertet...
# WARNING:root:Found data !
# WARNING:root:last data for L'Avenc - Tavertet is 2016
# WARNING:root:Loading estació L'Esquirol...
# WARNING:root:Found data !
# WARNING:root:last data for L'Esquirol is 2014
# WARNING:root:Loading estació L'Esquirol Sud...
# WARNING:root:Found data !
# WARNING:root:last data for L'Esquirol Sud is 2015
# WARNING:root:Loading estació Malla...
# WARNING:root:Found data !
# WARNING:root:last data for Malla is 2015
# WARNING:root:Loading estació Manlleu...
# WARNING:root:Found data !
# WARNING:root:last data for Manlleu is 2014
# WARNING:root:Loading estació Manlleu - Riu Ter...
# WARNING:root:No data found for Manlleu - Riu Ter
# WARNING:root:Loading estació Montseny "Vilar de la Castanya"...
# WARNING:root:Found data !
# WARNING:root:last data for Montseny "Vilar de la Castanya" is 2017
# WARNING:root:Loading estació Muntanyola "Fontanelles"...
# WARNING:root:Found data !
# WARNING:root:last data for Muntanyola "Fontanelles" is 2015
# WARNING:root:Loading estació Olost "Mas Lliscàs"...
# WARNING:root:Found data !
# WARNING:root:last data for Olost "Mas Lliscàs" is 2014
# WARNING:root:Loading estació Olost SE...
# WARNING:root:No data found for Olost SE
# WARNING:root:Loading estació Olost "Trasserra"...
# WARNING:root:Found data !
# WARNING:root:last data for Olost "Trasserra" is 2018
# WARNING:root:Loading estació Oristà SW...
# WARNING:root:No data found for Oristà SW
# WARNING:root:Loading estació Parador de Sau E...
# WARNING:root:No data found for Parador de Sau E
# WARNING:root:Loading estació Prats de Lluçanès Aemet...
# WARNING:root:Found data !
# WARNING:root:last data for Prats de Lluçanès Aemet is 2016
# WARNING:root:Loading estació Pruit "El Coll" Rupit...
# WARNING:root:Found data !
# WARNING:root:last data for Pruit "El Coll" Rupit is 2019
# WARNING:root:Loading estació Puigsagordi...
# WARNING:root:Found data !
# WARNING:root:last data for Puigsagordi is 2017
# WARNING:root:Loading estació Puigsagordi SE...
# WARNING:root:No data found for Puigsagordi SE
# WARNING:root:Loading estació TOOLIK LAKE-Alaska...
# WARNING:root:No data found for TOOLIK LAKE-Alaska
# WARNING:root:Loading estació NORDERNEY-Alemanya...
# WARNING:root:No data found for NORDERNEY-Alemanya
# WARNING:root:Loading estació OBERSTDORF-Alemanya...
# WARNING:root:No data found for OBERSTDORF-Alemanya
# WARNING:root:Loading estació VORDERLOIPLSAU-Alemanya...
# WARNING:root:No data found for VORDERLOIPLSAU-Alemanya
# WARNING:root:Loading estació ZUGSPITZE-Alemanya...
# WARNING:root:No data found for ZUGSPITZE-Alemanya
# WARNING:root:Loading estació ZUGSPITZE-Alemanya...
# WARNING:root:No data found for ZUGSPITZE-Alemanya
# WARNING:root:Loading estació GARS O'HIGGINS-Antàrtida...
# WARNING:root:No data found for GARS O'HIGGINS-Antàrtida
# WARNING:root:Loading estació PALMER STATION-Antàrtida...
# WARNING:root:No data found for PALMER STATION-Antàrtida
# WARNING:root:Loading estació FURKAJOCH-Àustria...
# WARNING:root:No data found for FURKAJOCH-Àustria
# WARNING:root:Loading estació SAALACH-Àustria...
# WARNING:root:No data found for SAALACH-Àustria
# WARNING:root:Loading estació SAALFELDEN-Àustria...
# WARNING:root:No data found for SAALFELDEN-Àustria
# WARNING:root:Loading estació SCHLEGEIS-Àustria...
# WARNING:root:No data found for SCHLEGEIS-Àustria
# WARNING:root:Loading estació SONNBLICK-Àustria...
# WARNING:root:No data found for SONNBLICK-Àustria
# WARNING:root:Loading estació PIC DU MIDI-França...
# WARNING:root:No data found for PIC DU MIDI-França
# WARNING:root:Loading estació FREYA GLETSCHER-Groenlàndia...
# WARNING:root:No data found for FREYA GLETSCHER-Groenlàndia
# WARNING:root:Loading estació MALCESINE-Itàlia...
# WARNING:root:No data found for MALCESINE-Itàlia
# WARNING:root:Loading estació NY-ÅLESUND-Noruega...
# WARNING:root:No data found for NY-ÅLESUND-Noruega
# WARNING:root:Loading estació KONKORDIAHÜTTE-Suïssa...
# WARNING:root:No data found for KONKORDIAHÜTTE-Suïssa
# WARNING:root:Loading estació VOLCÀ POÁS-Costa Rica...
# WARNING:root:No data found for VOLCÀ POÁS-Costa Rica
# WARNING:root:Loading estació VOLCÀ TURRIALBA-Costa Rica...
# WARNING:root:No data found for VOLCÀ TURRIALBA-Costa Rica
# WARNING:root:Loading estació VOLCÀ KILAUEA-Hawaii...
# WARNING:root:No data found for VOLCÀ KILAUEA-Hawaii
# WARNING:root:Loading estació CRÀTER BORY-Illa Reunió...
# WARNING:root:No data found for CRÀTER BORY-Illa Reunió
# WARNING:root:Loading estació VOLCÀ YASUR-Vanuatu...
# WARNING:root:No data found for VOLCÀ YASUR-Vanuatu
# WARNING:root:Loading estació Roda de Ter...
# WARNING:root:No data found for Roda de Ter
# WARNING:root:Loading estació Roda de Ter "Pla Xic"...
# WARNING:root:Found data !
# WARNING:root:last data for Roda de Ter "Pla Xic" is 2018
# WARNING:root:Loading estació Roda de Ter "Centre"...
# WARNING:root:Found data !
# WARNING:root:last data for Roda de Ter "Centre" is 2018
# WARNING:root:Loading estació Rupit...
# WARNING:root:Found data !
# WARNING:root:last data for Rupit is 2014
# WARNING:root:Loading estació St.Bartomeu del Grau SE...
# WARNING:root:No data found for St.Bartomeu del Grau SE
# WARNING:root:Loading estació St.Boi de Lluçanès...
# WARNING:root:Found data !
# WARNING:root:last data for St.Boi de Lluçanès is 2014
# WARNING:root:Loading estació St.Julià Vilatorta "Font d'en Pep"...
# WARNING:root:Found data !
# WARNING:root:last data for St.Julià Vilatorta "Font d'en Pep" is 2014
# WARNING:root:Loading estació St.Martí Sescorts...
# WARNING:root:Found data !
# WARNING:root:last data for St.Martí Sescorts is 2018
# WARNING:root:Loading estació St.Pere de Casserres...
# WARNING:root:Found data !
# WARNING:root:last data for St.Pere de Casserres is 2015
# WARNING:root:Loading estació St.Pere de Torelló...
# WARNING:root:Found data !
# WARNING:root:last data for St.Pere de Torelló is 2014
# WARNING:root:Loading estació St.Quirze de Besora...
# WARNING:root:Found data !
# WARNING:root:last data for St.Quirze de Besora is 2016
# WARNING:root:Loading estació St.Quirze de Besora - Riu Ter...
# WARNING:root:No data found for St.Quirze de Besora - Riu Ter
# WARNING:root:Loading estació Sant Sebastià NE...
# WARNING:root:No data found for Sant Sebastià NE
# WARNING:root:Loading estació St.Vicenç de Torelló Escoles...
# WARNING:root:Found data !
# WARNING:root:last data for St.Vicenç de Torelló Escoles is 2016
# WARNING:root:Loading estació Sta.Cecília de Voltregà...
# WARNING:root:Found data !
# WARNING:root:last data for Sta.Cecília de Voltregà is 2016
# WARNING:root:Loading estació Sant Eulàlia de R....
# WARNING:root:No data found for Sant Eulàlia de R.
# WARNING:root:Loading estació Sta.Eulàlia de Riuprimer...
# WARNING:root:Found data !
# WARNING:root:last data for Sta.Eulàlia de Riuprimer is 2014
# WARNING:root:Loading estació Sta.Maria de Besora...
# WARNING:root:Found data !
# WARNING:root:last data for Sta.Maria de Besora is 2014
# WARNING:root:Loading estació Santuari de Cabrera...
# WARNING:root:No data found for Santuari de Cabrera
# WARNING:root:Loading estació Sau - Pantà...
# WARNING:root:Found data !
# WARNING:root:last data for Sau - Pantà is 2014
# WARNING:root:Loading estació Sentfores...
# WARNING:root:Found data !
# WARNING:root:last data for Sentfores is 2014
# WARNING:root:Loading estació Sentfores 2 mòbil...
# WARNING:root:No data found for Sentfores 2 mòbil
# WARNING:root:Loading estació Seva "Els Sors"...
# WARNING:root:Found data !
# WARNING:root:last data for Seva "Els Sors" is 2014
# WARNING:root:Loading estació Seva "Els Roures"...
# WARNING:root:Found data !
# WARNING:root:last data for Seva "Els Roures" is 2017
# WARNING:root:Loading estació Sora...
# WARNING:root:Found data !
# WARNING:root:last data for Sora is 2016
# WARNING:root:Loading estació Sora N...
# WARNING:root:No data found for Sora N
# WARNING:root:Loading estació Taradell...
# WARNING:root:Found data !
# WARNING:root:last data for Taradell is 2014
# WARNING:root:Loading estació Taradell Institut IES...
# WARNING:root:Found data !
# WARNING:root:last data for Taradell Institut IES is 2020
# WARNING:root:Loading estació Taradell Nord...
# WARNING:root:Found data !
# WARNING:root:last data for Taradell Nord is 2015
# WARNING:root:Loading estació Tavèrnoles...
# WARNING:root:Found data !
# WARNING:root:last data for Tavèrnoles is 2014
# WARNING:root:Loading estació Tavertet...
# WARNING:root:Found data !
# WARNING:root:last data for Tavertet is 2015
# WARNING:root:Loading estació Tona IES...
# WARNING:root:Found data !
# WARNING:root:last data for Tona IES is 2014
# WARNING:root:Loading estació Torelló...
# WARNING:root:Found data !
# WARNING:root:last data for Torelló is 2016
# WARNING:root:Loading estació Torello S...
# WARNING:root:No data found for Torello S
# WARNING:root:Loading estació Vic...
# WARNING:root:Found data !
# WARNING:root:last data for Vic is 2014
# WARNING:root:Loading estació Vic Escorial Escola...
# WARNING:root:No data found for Vic Escorial Escola
# WARNING:root:Loading estació Vic Plaça...
# WARNING:root:No data found for Vic Plaça
# WARNING:root:Loading estació Vic Zona Universit.SE...
# WARNING:root:No data found for Vic Zona Universit.SE
# WARNING:root:Loading estació Vidrà...
# WARNING:root:Found data !
# WARNING:root:last data for Vidrà is 2014
# WARNING:root:Loading estació Viladrau...
# WARNING:root:Found data !
# WARNING:root:last data for Viladrau is 2017
# WARNING:root:Loading estació Viladrau...
# WARNING:root:No data found for Viladrau
# WARNING:root:Loading estació Vilanova de Sau NE...
# WARNING:root:No data found for Vilanova de Sau NE

# %% [markdown]
# ### Sanity checks

# %%
for estacio in df_res['estacio'].unique():
    df_test =df_res[df_res['estacio']==estacio].reset_index(drop=True)
    alt=df_test['altitude (m)'].iloc[0]
    lat=df_test['latitude'].iloc[0]
    lon=df_test['longitude'].iloc[0]
    for i in range(len(df_test)):
        assert alt == df_test['altitude (m)'].iloc[i], f'nop: {df_test["altitude (m)"].iloc[i]}'        
        assert lat == df_test['latitude'].iloc[i], f'nop: {df_test["latitude"].iloc[i]}'
        assert lon == df_test['longitude'].iloc[i], f'nop: {df_test["longitude"].iloc[i]}'

# %% [markdown]
# ### Type Casting

# %%
cols_to_float_cast=[
                'daily precipitation (l/m2)', 
                'temperature max (C)','temperature min (C)', 'temperature mean (C)',
                'humidity max (%)', 'humidity min (%)', 'humidity mean (%)',
                'wind max (km/h)', 
                'pressure max (hPa)', 'pressure min (hPa)', 'pressure mean (hPa)',
                'solar irradiation (J/m2)',
                'latitude', 'longitude', 'altitude (m)']
for column in cols_to_float_cast:
    df_res[column] = pd.to_numeric(df_res[column], errors='coerce').astype(float)

# %% [markdown]
# # Quick Data Analysis

# %%
fig, axs = plt.subplots(2, 2, figsize=(10, 8))
axs[0, 0].hist(df_res['date'], bins=15)
axs[0, 0].set_title('Histogram of MeteOsona Dates')
plt.xticks(rotation='vertical')
axs[0, 1].hist(df_res['altitude (m)'], bins=15)
axs[0, 1].set_title('Histogram of datapoints per altitude (m)')

axs[1, 0].hist(df_res[df_res['daily precipitation (l/m2)']>10]['daily precipitation (l/m2)'], bins=10)
axs[1, 0].set_title(f'Histogram of daily PP >10 ({int(100*len(df_res[df_res["daily precipitation (l/m2)"]>10])/len(df_res))}%)(mm/m2)')
axs[1, 0].set_xticklabels(axs[1, 0].get_xticks(), rotation=45)

axs[1, 1].hist(df_res['temperature mean (C)'], bins=10)
axs[1, 1].set_title('Hitogram of Temperatures (C)')


# Adjust the spacing between subplots
fig.tight_layout()

# Display the figure
plt.show()
# Out:
# /var/folders/76/bszhb_2s2k96xxhr9gsw39w80000gn/T/ipykernel_11935/2313964166.py:10: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[1, 0].set_xticklabels(axs[1, 0].get_xticks(), rotation=45)

# %%
df_res
# Out:
#        day daily precipitation (l/m2) temperature max (C) temperature min (C)
# 0        1                        0.0                17.7                 6.6  \
# 1        2                        0.0                13.6                 5.9
# 2        3                        0.0                12.6                 4.2
# 3        4                        0.4                13.1                 3.4
# 4        5                        0.0                13.5                 3.1
# ...     ..                        ...                 ...                 ...
# 107246  27                        0.2                11.2                 0.1
# 107247  28                        0.2                11.2                 1.7
# 107248  29                        0.0                 5.9                 3.2
# 107249  30                        0.2                 9.5                 1.6
# 107250  31                        0.0                 6.2                -1.2
#
#        temperature mean (C) humidity max (%) humidity min (%)
# 0                      11.4             76.0             36.0  \
# 1                       9.3             85.0             50.0
# 2                       8.1             96.0             74.0
# 3                       8.5             97.0             67.0
# 4                       8.8             94.0             55.0
# ...                     ...              ...              ...
# 107246                  4.8             97.0             75.0
# 107247                  5.8             96.0             61.0
# 107248                  4.7             96.0             88.0
# 107249                  5.0             96.0             75.0
# 107250                  3.1             96.0             86.0
#
#        humidity mean (%) wind max (km/h) wind dir pressure max (hPa)
# 0                   51.7            22.5        W             1024.8  \
# 1                   66.5             9.7      NNW             1025.0
# 2                   88.5            19.3      SSW             1030.3
# 3                   85.1            17.7      NNW             1032.3
# 4                   78.3            16.1      NNW             1030.2
# ...                  ...             ...      ...                ...
# 107246              92.3             4.8       SE             1030.8
# 107247              83.7             8.0      SSE             1033.9
# 107248              94.6             3.2       SE             1034.2
# 107249              89.2             6.4       SE             1035.8
# 107250              92.7             4.8      SSE             1035.4
#
#        pressure min (hPa) pressure mean (hPa) solar irradiation (J/m2)
# 0                  1022.3              1024.5                           \
# 1                  1021.1              1022.5
# 2                  1024.3              1024.6
# 3                  1029.6              1030.0
# 4                  1023.3              1029.0
# ...                   ...                 ...                      ...
# 107246             1028.3              1029.2
# 107247             1030.4              1030.7
# 107248             1031.9              1033.2
# 107249             1032.7              1033.3
# 107250             1032.3              1033.7
#
#               date   latitude  longitude  altitude (m)   estacio
# 0       2023-01-01  42.120762   2.100802         871.0    Alpens
# 1       2023-01-02  42.120762   2.100802         871.0    Alpens
# 2       2023-01-03  42.120762   2.100802         871.0    Alpens
# 3       2023-01-04  42.120762   2.100802         871.0    Alpens
# 4       2023-01-05  42.120762   2.100802         871.0    Alpens
# ...            ...        ...        ...           ...       ...
# 107246  2019-12-27  41.851029   2.391475         798.0  Viladrau
# 107247  2019-12-28  41.851029   2.391475         798.0  Viladrau
# 107248  2019-12-29  41.851029   2.391475         798.0  Viladrau
# 107249  2019-12-30  41.851029   2.391475         798.0  Viladrau
# 107250  2019-12-31  41.851029   2.391475         798.0  Viladrau
#
# [107251 rows x 19 columns]

# %%
len(estacions_dict)
# Out:
# 114

# %%
alt
# Out:
# 798.0

# %%
data
# Out:
# [[], []]

# %%
df.copy()
# Out:
# Empty DataFrame
# Columns: [day, daily precipitation (l/m2), temperature max (C), temperature min (C), temperature mean (C), humidity max (%), humidity min (%), humidity mean (%), wind max (km/h), wind dir, pressure max (hPa), pressure min (hPa), pressure mean (hPa), solar irradiation (J/m2)]
# Index: []

# %%
import pandas as pd

# Define column names and sub-names
# Define column names and sub-names
column_names = ['day', 
                'daily precipitation (l/m2)', 
                'temperature max (C)','temperature min (C)', 'temperature mean (C)',
                'humidity max (%)', 'humidity min (%)', 'humidity mean (%)',
                'wind max (km/h)', 'wind dir', 
                'pressure max (hPa)', 'pressure min (hPa)', 'pressure mean (hPa)',
                'solar irradiation (J/m2)']
# Create an empty dataframe
df = pd.DataFrame(columns=column_names)

# Print the dataframe
df
# Out:
# Empty DataFrame
# Columns: [day, daily precipitation (l/m2), temperature max (C), temperature min (C), temperature mean (C), humidity max (%), humidity min (%), humidity mean (%), wind max (km/h), wind dir, pressure max (hPa), pressure min (hPa), pressure mean (hPa), solar irradiation (J/m2)]
# Index: []

# %%
len(df.columns)
# Out:
# 14

# %%
data
# Out:
# [[],
#  [],
#  ['1',
#   '11.0',
#   '17.8',
#   '8.4',
#   '13.7',
#   '94.0',
#   '65.0',
#   '87.6',
#   '12.9',
#   'E',
#   '1016.0',
#   '1014.1',
#   '1015.8',
#   ''],
#  ['2',
#   '1.8',
#   '22.1',
#   '7.7',
#   '13.8',
#   '95.0',
#   '49.0',
#   '85.4',
#   '12.9',
#   'E',
#   '1015.5',
#   '1012.7',
#   '1015.2',
#   ''],
#  ['3',
#   '0.4',
#   '20.6',
#   '8.7',
#   '13.5',
#   '95.0',
#   '62.0',
#   '85.0',
#   '20.9',
#   'ENE',
#   '1015.6',
#   '1013.0',
#   '1014.1',
#   ''],
#  ['4',
#   '8.6',
#   '19.6',
#   '8.2',
#   '13.2',
#   '94.0',
#   '64.0',
#   '86.3',
#   '12.9',
#   'S',
#   '1017.2',
#   '1014.4',
#   '1015.0',
#   ''],
#  ['5',
#   '8.0',
#   '19.6',
#   '9.9',
#   '14.5',
#   '95.0',
#   '65.0',
#   '88.3',
#   '16.1',
#   'WSW',
#   '1016.9',
#   '1014.1',
#   '1016.8',
#   ''],
#  ['6',
#   '6.6',
#   '21.8',
#   '9.4',
#   '15.3',
#   '96.0',
#   '53.0',
#   '85.7',
#   '17.7',
#   'ENE',
#   '1016.3',
#   '1014.7',
#   '1016.1',
#   ''],
#  ['7',
#   '0.0',
#   '18.9',
#   '11.3',
#   '14.5',
#   '95.0',
#   '76.0',
#   '88.1',
#   '20.9',
#   'SSE',
#   '1016.3',
#   '1013.8',
#   '1015.3',
#   ''],
#  ['8',
#   '0.0',
#   '21.3',
#   '11.2',
#   '15.9',
#   '96.0',
#   '60.0',
#   '83.2',
#   '17.7',
#   'SW',
#   '1014.0',
#   '1009.7',
#   '1013.6',
#   ''],
#  ['9',
#   '0.0',
#   '22.7',
#   '13.9',
#   '17.1',
#   '95.0',
#   '63.0',
#   '85.1',
#   '24.1',
#   'WSW',
#   '1012.6',
#   '1007.5',
#   '1010.0',
#   ''],
#  ['10',
#   '19.0',
#   '23.1',
#   '12.2',
#   '16.9',
#   '95.0',
#   '58.0',
#   '87.7',
#   '12.9',
#   'ENE',
#   '1014.7',
#   '1011.2',
#   '1012.3',
#   ''],
#  ['11',
#   '0.6',
#   '22.5',
#   '11.7',
#   '16.2',
#   '96.0',
#   '59.0',
#   '83.9',
#   '16.1',
#   'ENE',
#   '1015.7',
#   '1013.4',
#   '1014.5',
#   ''],
#  ['12',
#   '0.0',
#   '23.9',
#   '11.7',
#   '18.0',
#   '91.0',
#   '54.0',
#   '74.7',
#   '19.3',
#   'E',
#   '1013.7',
#   '1009.1',
#   '1013.3',
#   ''],
#  ['13',
#   '14.8',
#   '21.0',
#   '11.2',
#   '16.2',
#   '95.0',
#   '62.0',
#   '88.7',
#   '17.7',
#   'ENE',
#   '1009.8',
#   '1006.1',
#   '1009.3',
#   ''],
#  ['14',
#   '0.2',
#   '24.8',
#   '11.3',
#   '17.4',
#   '95.0',
#   '49.0',
#   '81.1',
#   '9.7',
#   'E',
#   '1016.2',
#   '1008.9',
#   '1009.4',
#   ''],
#  ['15',
#   '0.0',
#   '24.7',
#   '11.4',
#   '17.3',
#   '93.0',
#   '42.0',
#   '73.7',
#   '14.5',
#   'ENE',
#   '1018.8',
#   '1015.3',
#   '1015.9',
#   ''],
#  ['16',
#   '0.0',
#   '26.8',
#   '11.6',
#   '19.9',
#   '88.0',
#   '42.0',
#   '63.9',
#   '12.9',
#   'ESE',
#   '1018.5',
#   '1015.3',
#   '1017.8',
#   ''],
#  ['17',
#   '1.8',
#   '28.7',
#   '12.9',
#   '20.1',
#   '94.0',
#   '42.0',
#   '74.0',
#   '14.5',
#   'SSE',
#   '1016.7',
#   '1012.6',
#   '1015.9',
#   ''],
#  ['18',
#   '0.2',
#   '23.1',
#   '13.7',
#   '17.7',
#   '90.0',
#   '55.0',
#   '76.8',
#   '16.1',
#   'WSW',
#   '1015.6',
#   '1010.7',
#   '1013.0',
#   ''],
#  ['19',
#   '0.0',
#   '24.0',
#   '13.4',
#   '18.2',
#   '77.0',
#   '52.0',
#   '64.3',
#   '20.9',
#   'WSW',
#   '1015.3',
#   '1010.9',
#   '1014.6',
#   ''],
#  ['20',
#   '0.0',
#   '28.3',
#   '16.4',
#   '21.7',
#   '88.0',
#   '43.0',
#   '68.1',
#   '11.3',
#   'ENE',
#   '1013.9',
#   '1008.7',
#   '1010.1',
#   ''],
#  ['21',
#   '0.0',
#   '25.8',
#   '16.6',
#   '20.7',
#   '92.0',
#   '67.0',
#   '80.1',
#   '20.9',
#   'E',
#   '1014.0',
#   '1010.4',
#   '1013.1',
#   ''],
#  ['22',
#   '0.0',
#   '25.2',
#   '14.8',
#   '20.2',
#   '94.0',
#   '54.0',
#   '79.1',
#   '16.1',
#   'W',
#   '1021.8',
#   '1012.2',
#   '1014.8',
#   ''],
#  ['23',
#   '0.0',
#   '27.0',
#   '14.2',
#   '19.5',
#   '94.0',
#   '54.0',
#   '78.4',
#   '12.9',
#   'ENE',
#   '1023.0',
#   '1020.2',
#   '1021.8',
#   ''],
#  ['24',
#   '0.0',
#   '29.6',
#   '13.7',
#   '20.9',
#   '94.0',
#   '46.0',
#   '72.6',
#   '14.5',
#   'E',
#   '1021.0',
#   '1016.1',
#   '1020.7',
#   ''],
#  ['25',
#   '0.0',
#   '31.2',
#   '14.9',
#   '22.2',
#   '92.0',
#   '42.0',
#   '67.5',
#   '9.7',
#   'E',
#   '1018.9',
#   '1015.9',
#   '1018.0',
#   ''],
#  ['26',
#   '0.0',
#   '30.8',
#   '16.8',
#   '22.9',
#   '82.0',
#   '42.0',
#   '64.5',
#   '12.9',
#   'ENE',
#   '1018.9',
#   '1016.0',
#   '1018.5',
#   ''],
#  ['27',
#   '0.0',
#   '27.6',
#   '14.8',
#   '22.9',
#   '87.0',
#   '55.0',
#   '73.7',
#   '9.7',
#   'E',
#   '1018.2',
#   '1014.9',
#   '1017.1',
#   ''],
#  ['28',
#   '1.2',
#   '27.5',
#   '15.5',
#   '18.1',
#   '93.0',
#   '56.0',
#   '90.2',
#   '12.9',
#   'E',
#   '1015.4',
#   '1012.9',
#   '1014.7',
#   ''],
#  ['29',
#   '1.0',
#   '25.7',
#   '15.4',
#   '19.6',
#   '94.0',
#   '56.0',
#   '80.7',
#   '12.9',
#   'NE',
#   '1016.4',
#   '1013.2',
#   '1015.3',
#   '']]

# %%
data = {
    'temperature': {'min': 10, 'max': 25, 'mean': 17.5},
    'pressure': {'min': 15, 'max': 30, 'mean': 22.5}
}

# Create the DataFrame
df = pd.DataFrame(data, index=[0, 1])

# Create the MultiIndex for columns
columns = pd.MultiIndex.from_product([df.columns, ['min', 'max', 'mean']],
                                     names=['parameter', 'stat'])

# Reindex the DataFrame with the MultiIndex columns
df = df.reindex(columns=columns)

# %%
df.columns
# Out:
# MultiIndex([('temperature',  'min'),
#             ('temperature',  'max'),
#             ('temperature', 'mean'),
#             (   'pressure',  'min'),
#             (   'pressure',  'max'),
#             (   'pressure', 'mean')],
#            names=['parameter', 'stat'])

# %%
data = {
    'temperature': {'min': 10, 'max': 25, 'mean': 17.5},
    'pressure': {'min': 15, 'max': 30, 'mean': 22.5},
    'humidity': [40, 50]  # New column without sub-columns
}

# Create the DataFrame
df = pd.DataFrame(data, index=[0, 1])

# Create the MultiIndex for columns
columns = pd.MultiIndex.from_product([df.columns, ['min', 'max', 'mean']],
                                     names=['parameter', 'stat'])
columns = columns.append(pd.Index([df.columns[-1]], name='parameter'))  # Add column without sub-columns

# Reindex the DataFrame with the MultiIndex columns
df = df.reindex(columns=columns)

# %%
df
# Out:
#    (temperature, min)  (temperature, max)  (temperature, mean)
# 0                 NaN                 NaN                  NaN  \
# 1                 NaN                 NaN                  NaN
#
#    (pressure, min)  (pressure, max)  (pressure, mean)  (humidity, min)
# 0              NaN              NaN               NaN              NaN  \
# 1              NaN              NaN               NaN              NaN
#
#    (humidity, max)  (humidity, mean)  humidity
# 0              NaN               NaN        40
# 1              NaN               NaN        50

# %%
df.columns
# Out:
# Index([ ('temperature', 'min'),  ('temperature', 'max'),
#        ('temperature', 'mean'),     ('pressure', 'min'),
#            ('pressure', 'max'),    ('pressure', 'mean'),
#            ('humidity', 'min'),     ('humidity', 'max'),
#           ('humidity', 'mean'),              'humidity'],
#       dtype='object')
